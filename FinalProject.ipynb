# %% [markdown]
# You may add additional cells as necessary (Insert-> Cell above/cell below) in each section.
#
# Please try to keep code related to each section under the appropriate heading.
#
# Also, please provide comments using the # sign in code cells or add additional Markdown cells to provide lengthier explanations if necessary (Insert-> Cell above or cell below, click in new cell, Cell->Cell Type->Markdown).
#
# You are encouraged to do this work on your own and avoid any appearance of academic misconduct. You are also encouraged to ask questions of the instructor and each other when the need arises. Please use your best judgement.

# %% [markdown]
# __Import the data from the CSV files

# %%
import numpy as np
import pandas as pd
weather2020_df = pd.read_csv("w2020.csv", usecols=["Date/Time", "Max Temp (°C)", "Total Precip (mm)"])
weather2021_df = pd.read_csv("w2021.csv", usecols=["Date/Time", "Max Temp (°C)", "Total Precip (mm)"])
network_df = pd.read_csv("NetworkData.csv", usecols=["Date", "Delay (ms)", "Down (Mbps)", "Up (Mbps)", "Day"])

# %% [markdown]
# __Combine the data files.

# %%
weather_df = pd.concat([weather2020_df,weather2021_df], axis=0)
network_df = network_df.rename(columns={"Date":"Date/Time"})
complete_df = pd.merge(network_df, weather_df, on="Date/Time")
complete_df.head()
# Out:
#     Date/Time  Delay (ms)  Down (Mbps)  Up (Mbps)  Day  Max Temp (°C)  \
# 0  2020-09-09          78        71.12       6.46    4           27.0
# 1  2020-09-10          80        70.44      13.86    5           27.0
# 2  2020-09-11          74        72.54      13.92    6           18.0
# 3  2020-09-13          85        69.44      11.71    1           23.5
# 4  2020-09-14          75        74.81       5.85    2           18.5
#
#    Total Precip (mm)
# 0                0.0
# 1                0.0
# 2                0.0
# 3               13.0
# 4                0.0

# %% [markdown]
# __Plot the data

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
x = complete_df["Date/Time"]
ax1.plot(x, complete_df["Down (Mbps)"], "r-")
ax2.plot(x, complete_df["Max Temp (°C)"], "b-")

ax1.set_xlabel("Year")
ax1.set_ylabel("Speed (Mbps)", color="r")
ax2.set_ylabel("Temp (°C)", color="b")

plt.show()

# %% [markdown]
# __Calculate the central tendencies

# %%
print("The mean: " + str(complete_df["Up (Mbps)"].mean()))
print("The median: " + str(complete_df["Up (Mbps)"].median()))
print("The mode: " + str(complete_df["Up (Mbps)"].mode()))
# Out:
# The mean: 9.424050000000005
# The median: 10.035
# The mode: 0    13.88
# dtype: float64

# %% [markdown]
# __Convert to a dictionary

# %%
complete_dict = complete_df.to_dict("records");
complete_dict
# Out:
# [{'Date/Time': '2020-09-09',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.12,
#   'Up (Mbps)': 6.46,
#   'Day': 4,
#   'Max Temp (°C)': 27.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-10',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.44,
#   'Up (Mbps)': 13.86,
#   'Day': 5,
#   'Max Temp (°C)': 27.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-11',
#   'Delay (ms)': 74,
#   'Down (Mbps)': 72.54,
#   'Up (Mbps)': 13.92,
#   'Day': 6,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-13',
#   'Delay (ms)': 85,
#   'Down (Mbps)': 69.44,
#   'Up (Mbps)': 11.71,
#   'Day': 1,
#   'Max Temp (°C)': 23.5,
#   'Total Precip (mm)': 13.0},
#  {'Date/Time': '2020-09-14',
#   'Delay (ms)': 75,
#   'Down (Mbps)': 74.81,
#   'Up (Mbps)': 5.85,
#   'Day': 2,
#   'Max Temp (°C)': 18.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-15',
#   'Delay (ms)': 117,
#   'Down (Mbps)': 72.7,
#   'Up (Mbps)': 12.41,
#   'Day': 3,
#   'Max Temp (°C)': 19.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-16',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.53,
#   'Up (Mbps)': 3.01,
#   'Day': 4,
#   'Max Temp (°C)': 21.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-17',
#   'Delay (ms)': 99,
#   'Down (Mbps)': 66.72,
#   'Up (Mbps)': 14.09,
#   'Day': 5,
#   'Max Temp (°C)': 22.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-18',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 70.25,
#   'Up (Mbps)': 11.48,
#   'Day': 6,
#   'Max Temp (°C)': 17.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-19',
#   'Delay (ms)': 74,
#   'Down (Mbps)': 69.19,
#   'Up (Mbps)': 14.51,
#   'Day': 7,
#   'Max Temp (°C)': 15.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-20',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 70.49,
#   'Up (Mbps)': 10.85,
#   'Day': 1,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-21',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 71.57,
#   'Up (Mbps)': 6.36,
#   'Day': 2,
#   'Max Temp (°C)': 19.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-22',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 70.35,
#   'Up (Mbps)': 13.35,
#   'Day': 3,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-23',
#   'Delay (ms)': 74,
#   'Down (Mbps)': 71.29,
#   'Up (Mbps)': 13.91,
#   'Day': 4,
#   'Max Temp (°C)': 23.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-24',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 72.2,
#   'Up (Mbps)': 12.69,
#   'Day': 5,
#   'Max Temp (°C)': 23.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-25',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 71.88,
#   'Up (Mbps)': 13.15,
#   'Day': 6,
#   'Max Temp (°C)': 26.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-26',
#   'Delay (ms)': 73,
#   'Down (Mbps)': 70.06,
#   'Up (Mbps)': 3.99,
#   'Day': 7,
#   'Max Temp (°C)': 25.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-27',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 71.91,
#   'Up (Mbps)': 5.3,
#   'Day': 1,
#   'Max Temp (°C)': 25.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-09-28',
#   'Delay (ms)': 73,
#   'Down (Mbps)': 69.48,
#   'Up (Mbps)': 4.95,
#   'Day': 2,
#   'Max Temp (°C)': 25.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2020-09-29',
#   'Delay (ms)': 86,
#   'Down (Mbps)': 71.89,
#   'Up (Mbps)': 6.46,
#   'Day': 3,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 13.8},
#  {'Date/Time': '2020-09-30',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 70.62,
#   'Up (Mbps)': 13.16,
#   'Day': 4,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 22.1},
#  {'Date/Time': '2020-10-01',
#   'Delay (ms)': 124,
#   'Down (Mbps)': 74.74,
#   'Up (Mbps)': 13.86,
#   'Day': 5,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 3.2},
#  {'Date/Time': '2020-10-02',
#   'Delay (ms)': 70,
#   'Down (Mbps)': 70.01,
#   'Up (Mbps)': 6.41,
#   'Day': 6,
#   'Max Temp (°C)': 15.0,
#   'Total Precip (mm)': 3.0},
#  {'Date/Time': '2020-10-03',
#   'Delay (ms)': 71,
#   'Down (Mbps)': 70.84,
#   'Up (Mbps)': 13.97,
#   'Day': 7,
#   'Max Temp (°C)': 12.0,
#   'Total Precip (mm)': 0.2},
#  {'Date/Time': '2020-10-04',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 70.6,
#   'Up (Mbps)': 7.1,
#   'Day': 1,
#   'Max Temp (°C)': 17.0,
#   'Total Precip (mm)': 1.4},
#  {'Date/Time': '2020-10-05',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.75,
#   'Up (Mbps)': 11.31,
#   'Day': 2,
#   'Max Temp (°C)': 15.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-10-06',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 69.07,
#   'Up (Mbps)': 14.94,
#   'Day': 3,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 20.0},
#  {'Date/Time': '2020-10-07',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 72.09,
#   'Up (Mbps)': 7.19,
#   'Day': 4,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 5.0},
#  {'Date/Time': '2020-10-08',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.36,
#   'Up (Mbps)': 7.13,
#   'Day': 5,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 1.8},
#  {'Date/Time': '2020-10-09',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 71.02,
#   'Up (Mbps)': 14.76,
#   'Day': 6,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-10-10',
#   'Delay (ms)': 120,
#   'Down (Mbps)': 71.66,
#   'Up (Mbps)': 13.43,
#   'Day': 7,
#   'Max Temp (°C)': 21.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-10-11',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.42,
#   'Up (Mbps)': 11.58,
#   'Day': 1,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-10-12',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.69,
#   'Up (Mbps)': 11.36,
#   'Day': 2,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 3.0},
#  {'Date/Time': '2020-10-13',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.15,
#   'Up (Mbps)': 4.51,
#   'Day': 3,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-10-14',
#   'Delay (ms)': 116,
#   'Down (Mbps)': 70.14,
#   'Up (Mbps)': 5.62,
#   'Day': 4,
#   'Max Temp (°C)': 23.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-10-15',
#   'Delay (ms)': 84,
#   'Down (Mbps)': 72.46,
#   'Up (Mbps)': 7.27,
#   'Day': 5,
#   'Max Temp (°C)': 19.0,
#   'Total Precip (mm)': 8.7},
#  {'Date/Time': '2020-10-16',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 69.7,
#   'Up (Mbps)': 4.89,
#   'Day': 6,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-10-17',
#   'Delay (ms)': 86,
#   'Down (Mbps)': 62.52,
#   'Up (Mbps)': 5.57,
#   'Day': 7,
#   'Max Temp (°C)': 14.0,
#   'Total Precip (mm)': 2.0},
#  {'Date/Time': '2020-10-18',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 72.06,
#   'Up (Mbps)': 6.25,
#   'Day': 1,
#   'Max Temp (°C)': 15.5,
#   'Total Precip (mm)': 2.0},
#  {'Date/Time': '2020-10-19',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 69.19,
#   'Up (Mbps)': 7.24,
#   'Day': 2,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 17.0},
#  {'Date/Time': '2020-10-20',
#   'Delay (ms)': 76,
#   'Down (Mbps)': 71.5,
#   'Up (Mbps)': 11.3,
#   'Day': 3,
#   'Max Temp (°C)': 17.0,
#   'Total Precip (mm)': 6.5},
#  {'Date/Time': '2020-10-21',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.59,
#   'Up (Mbps)': 13.88,
#   'Day': 4,
#   'Max Temp (°C)': 19.0,
#   'Total Precip (mm)': 5.3},
#  {'Date/Time': '2020-10-22',
#   'Delay (ms)': 115,
#   'Down (Mbps)': 72.08,
#   'Up (Mbps)': 4.81,
#   'Day': 5,
#   'Max Temp (°C)': 16.0,
#   'Total Precip (mm)': 3.0},
#  {'Date/Time': '2020-10-23',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 71.76,
#   'Up (Mbps)': 7.3,
#   'Day': 6,
#   'Max Temp (°C)': 23.0,
#   'Total Precip (mm)': 10.8},
#  {'Date/Time': '2020-10-24',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.82,
#   'Up (Mbps)': 11.38,
#   'Day': 7,
#   'Max Temp (°C)': 18.5,
#   'Total Precip (mm)': 0.2},
#  {'Date/Time': '2020-10-25',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.34,
#   'Up (Mbps)': 7.26,
#   'Day': 1,
#   'Max Temp (°C)': 12.0,
#   'Total Precip (mm)': 1.5},
#  {'Date/Time': '2020-10-26',
#   'Delay (ms)': 111,
#   'Down (Mbps)': 71.37,
#   'Up (Mbps)': 6.94,
#   'Day': 2,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-10-27',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 46.68,
#   'Up (Mbps)': 5.78,
#   'Day': 3,
#   'Max Temp (°C)': 11.5,
#   'Total Precip (mm)': 4.0},
#  {'Date/Time': '2020-10-28',
#   'Delay (ms)': 188,
#   'Down (Mbps)': 70.56,
#   'Up (Mbps)': 1.38,
#   'Day': 4,
#   'Max Temp (°C)': 11.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2020-10-29',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.02,
#   'Up (Mbps)': 6.82,
#   'Day': 5,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2020-10-30',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 71.31,
#   'Up (Mbps)': 7.48,
#   'Day': 6,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2020-10-31',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 72.2,
#   'Up (Mbps)': 6.85,
#   'Day': 7,
#   'Max Temp (°C)': 12.0,
#   'Total Precip (mm)': 0.4},
#  {'Date/Time': '2020-11-01',
#   'Delay (ms)': 86,
#   'Down (Mbps)': 70.82,
#   'Up (Mbps)': 6.26,
#   'Day': 1,
#   'Max Temp (°C)': 11.0,
#   'Total Precip (mm)': 9.0},
#  {'Date/Time': '2020-11-02',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 74.05,
#   'Up (Mbps)': 3.76,
#   'Day': 2,
#   'Max Temp (°C)': 8.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-03',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.04,
#   'Up (Mbps)': 9.76,
#   'Day': 3,
#   'Max Temp (°C)': 14.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-04',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 71.4,
#   'Up (Mbps)': 6.92,
#   'Day': 4,
#   'Max Temp (°C)': 17.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-05',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 14.55,
#   'Up (Mbps)': 13.0,
#   'Day': 5,
#   'Max Temp (°C)': 18.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-06',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.03,
#   'Up (Mbps)': 4.88,
#   'Day': 6,
#   'Max Temp (°C)': 15.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-07',
#   'Delay (ms)': 72,
#   'Down (Mbps)': 69.25,
#   'Up (Mbps)': 13.94,
#   'Day': 7,
#   'Max Temp (°C)': 15.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-08',
#   'Delay (ms)': 67,
#   'Down (Mbps)': 68.53,
#   'Up (Mbps)': 11.44,
#   'Day': 1,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-09',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.4,
#   'Up (Mbps)': 10.11,
#   'Day': 2,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-10',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 57.4,
#   'Up (Mbps)': 10.64,
#   'Day': 3,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-11',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.88,
#   'Up (Mbps)': 11.01,
#   'Day': 4,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-12',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.45,
#   'Up (Mbps)': 4.86,
#   'Day': 5,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-13',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 66.54,
#   'Up (Mbps)': 6.51,
#   'Day': 6,
#   'Max Temp (°C)': 10.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-14',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 71.14,
#   'Up (Mbps)': 11.39,
#   'Day': 7,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 2.4},
#  {'Date/Time': '2020-11-15',
#   'Delay (ms)': 155,
#   'Down (Mbps)': 66.53,
#   'Up (Mbps)': 7.37,
#   'Day': 1,
#   'Max Temp (°C)': 14.0,
#   'Total Precip (mm)': 6.6},
#  {'Date/Time': '2020-11-16',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.33,
#   'Up (Mbps)': 6.9,
#   'Day': 2,
#   'Max Temp (°C)': 6.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-17',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 71.62,
#   'Up (Mbps)': 1.98,
#   'Day': 3,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-18',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 73.63,
#   'Up (Mbps)': 13.77,
#   'Day': 4,
#   'Max Temp (°C)': 9.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-19',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.38,
#   'Up (Mbps)': 14.11,
#   'Day': 5,
#   'Max Temp (°C)': 14.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-20',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.55,
#   'Up (Mbps)': 12.27,
#   'Day': 6,
#   'Max Temp (°C)': 14.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-21',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.7,
#   'Up (Mbps)': 13.89,
#   'Day': 7,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-22',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 57.9,
#   'Up (Mbps)': 13.7,
#   'Day': 1,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 19.6},
#  {'Date/Time': '2020-11-23',
#   'Delay (ms)': 90,
#   'Down (Mbps)': 71.43,
#   'Up (Mbps)': 11.31,
#   'Day': 2,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-24',
#   'Delay (ms)': 84,
#   'Down (Mbps)': 70.0,
#   'Up (Mbps)': 6.18,
#   'Day': 3,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-25',
#   'Delay (ms)': 90,
#   'Down (Mbps)': 73.18,
#   'Up (Mbps)': 11.13,
#   'Day': 4,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 9.0},
#  {'Date/Time': '2020-11-26',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 70.7,
#   'Up (Mbps)': 11.95,
#   'Day': 5,
#   'Max Temp (°C)': 11.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-11-27',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 72.49,
#   'Up (Mbps)': 6.88,
#   'Day': 6,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-28',
#   'Delay (ms)': 84,
#   'Down (Mbps)': 69.28,
#   'Up (Mbps)': 9.36,
#   'Day': 7,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2020-11-29',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 66.82,
#   'Up (Mbps)': 10.86,
#   'Day': 1,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 1.2},
#  {'Date/Time': '2020-11-30',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.26,
#   'Up (Mbps)': 6.23,
#   'Day': 2,
#   'Max Temp (°C)': 6.0,
#   'Total Precip (mm)': 26.6},
#  {'Date/Time': '2020-12-01',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.47,
#   'Up (Mbps)': 14.59,
#   'Day': 3,
#   'Max Temp (°C)': 0.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-02',
#   'Delay (ms)': 85,
#   'Down (Mbps)': 71.51,
#   'Up (Mbps)': 12.72,
#   'Day': 4,
#   'Max Temp (°C)': 6.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-03',
#   'Delay (ms)': 85,
#   'Down (Mbps)': 45.79,
#   'Up (Mbps)': 2.81,
#   'Day': 5,
#   'Max Temp (°C)': 7.0,
#   'Total Precip (mm)': 0.3},
#  {'Date/Time': '2020-12-04',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 68.58,
#   'Up (Mbps)': 10.69,
#   'Day': 6,
#   'Max Temp (°C)': 7.0,
#   'Total Precip (mm)': 1.2},
#  {'Date/Time': '2020-12-05',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 71.67,
#   'Up (Mbps)': 6.27,
#   'Day': 7,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-06',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 70.23,
#   'Up (Mbps)': 11.51,
#   'Day': 1,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-07',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 71.56,
#   'Up (Mbps)': 14.3,
#   'Day': 2,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-08',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 70.78,
#   'Up (Mbps)': 6.17,
#   'Day': 3,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 1.2},
#  {'Date/Time': '2020-12-09',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 75.58,
#   'Up (Mbps)': 11.47,
#   'Day': 4,
#   'Max Temp (°C)': 4.5,
#   'Total Precip (mm)': 2.6},
#  {'Date/Time': '2020-12-10',
#   'Delay (ms)': 86,
#   'Down (Mbps)': 70.3,
#   'Up (Mbps)': 6.24,
#   'Day': 5,
#   'Max Temp (°C)': 6.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-11',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 73.26,
#   'Up (Mbps)': 12.06,
#   'Day': 6,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-12',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 71.66,
#   'Up (Mbps)': 13.33,
#   'Day': 7,
#   'Max Temp (°C)': 12.0,
#   'Total Precip (mm)': 8.0},
#  {'Date/Time': '2020-12-13',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.02,
#   'Up (Mbps)': 4.0,
#   'Day': 1,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-14',
#   'Delay (ms)': 87,
#   'Down (Mbps)': 53.73,
#   'Up (Mbps)': 11.42,
#   'Day': 2,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-15',
#   'Delay (ms)': 74,
#   'Down (Mbps)': 69.36,
#   'Up (Mbps)': 13.94,
#   'Day': 3,
#   'Max Temp (°C)': -0.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-16',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 70.68,
#   'Up (Mbps)': 13.88,
#   'Day': 4,
#   'Max Temp (°C)': -2.0,
#   'Total Precip (mm)': 4.0},
#  {'Date/Time': '2020-12-17',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 74.29,
#   'Up (Mbps)': 14.78,
#   'Day': 5,
#   'Max Temp (°C)': -3.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-18',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.24,
#   'Up (Mbps)': 7.4,
#   'Day': 6,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-19',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.48,
#   'Up (Mbps)': 6.24,
#   'Day': 7,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 3.2},
#  {'Date/Time': '2020-12-20',
#   'Delay (ms)': 75,
#   'Down (Mbps)': 68.24,
#   'Up (Mbps)': 14.23,
#   'Day': 1,
#   'Max Temp (°C)': 4.5,
#   'Total Precip (mm)': 0.8},
#  {'Date/Time': '2020-12-21',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.83,
#   'Up (Mbps)': 11.54,
#   'Day': 2,
#   'Max Temp (°C)': 4.5,
#   'Total Precip (mm)': 7.0},
#  {'Date/Time': '2020-12-22',
#   'Delay (ms)': 74,
#   'Down (Mbps)': 72.61,
#   'Up (Mbps)': 14.57,
#   'Day': 3,
#   'Max Temp (°C)': 4.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-24',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 79.16,
#   'Up (Mbps)': 5.38,
#   'Day': 5,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 12.0},
#  {'Date/Time': '2020-12-26',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.0,
#   'Up (Mbps)': 3.94,
#   'Day': 7,
#   'Max Temp (°C)': -1.0,
#   'Total Precip (mm)': 4.0},
#  {'Date/Time': '2020-12-27',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.97,
#   'Up (Mbps)': 6.21,
#   'Day': 1,
#   'Max Temp (°C)': 6.5,
#   'Total Precip (mm)': 14.6},
#  {'Date/Time': '2020-12-28',
#   'Delay (ms)': 75,
#   'Down (Mbps)': 68.06,
#   'Up (Mbps)': 11.68,
#   'Day': 2,
#   'Max Temp (°C)': 5.0,
#   'Total Precip (mm)': 0.4},
#  {'Date/Time': '2020-12-29',
#   'Delay (ms)': 71,
#   'Down (Mbps)': 70.69,
#   'Up (Mbps)': 6.37,
#   'Day': 3,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2020-12-30',
#   'Delay (ms)': 118,
#   'Down (Mbps)': 71.46,
#   'Up (Mbps)': 12.88,
#   'Day': 4,
#   'Max Temp (°C)': 6.5,
#   'Total Precip (mm)': 17.4},
#  {'Date/Time': '2020-12-31',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 68.48,
#   'Up (Mbps)': 11.29,
#   'Day': 5,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-01',
#   'Delay (ms)': 90,
#   'Down (Mbps)': 72.44,
#   'Up (Mbps)': 6.98,
#   'Day': 6,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 18.0},
#  {'Date/Time': '2021-01-02',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 69.99,
#   'Up (Mbps)': 13.69,
#   'Day': 7,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.5},
#  {'Date/Time': '2021-01-03',
#   'Delay (ms)': 86,
#   'Down (Mbps)': 70.17,
#   'Up (Mbps)': 7.1,
#   'Day': 1,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-04',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 71.25,
#   'Up (Mbps)': 14.61,
#   'Day': 2,
#   'Max Temp (°C)': 2.5,
#   'Total Precip (mm)': 0.5},
#  {'Date/Time': '2021-01-05',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 72.79,
#   'Up (Mbps)': 4.83,
#   'Day': 3,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-06',
#   'Delay (ms)': 83,
#   'Down (Mbps)': 71.5,
#   'Up (Mbps)': 11.75,
#   'Day': 4,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-07',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 72.78,
#   'Up (Mbps)': 13.04,
#   'Day': 5,
#   'Max Temp (°C)': -0.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-08',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 73.15,
#   'Up (Mbps)': 6.41,
#   'Day': 6,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-09',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 73.94,
#   'Up (Mbps)': 11.18,
#   'Day': 7,
#   'Max Temp (°C)': 4.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-10',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 70.8,
#   'Up (Mbps)': 14.15,
#   'Day': 1,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2021-01-11',
#   'Delay (ms)': 75,
#   'Down (Mbps)': 72.74,
#   'Up (Mbps)': 6.41,
#   'Day': 2,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-12',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 73.53,
#   'Up (Mbps)': 5.59,
#   'Day': 3,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-13',
#   'Delay (ms)': 92,
#   'Down (Mbps)': 71.78,
#   'Up (Mbps)': 6.86,
#   'Day': 4,
#   'Max Temp (°C)': 5.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-14',
#   'Delay (ms)': 147,
#   'Down (Mbps)': 72.56,
#   'Up (Mbps)': 4.97,
#   'Day': 5,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.2},
#  {'Date/Time': '2021-01-15',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 71.83,
#   'Up (Mbps)': 14.63,
#   'Day': 6,
#   'Max Temp (°C)': 6.0,
#   'Total Precip (mm)': 3.0},
#  {'Date/Time': '2021-01-16',
#   'Delay (ms)': 119,
#   'Down (Mbps)': 73.02,
#   'Up (Mbps)': 14.5,
#   'Day': 7,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.8},
#  {'Date/Time': '2021-01-17',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 70.66,
#   'Up (Mbps)': 4.86,
#   'Day': 1,
#   'Max Temp (°C)': 4.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-18',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 73.27,
#   'Up (Mbps)': 7.52,
#   'Day': 2,
#   'Max Temp (°C)': 2.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-19',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 58.5,
#   'Up (Mbps)': 7.44,
#   'Day': 3,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.4},
#  {'Date/Time': '2021-01-20',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 70.91,
#   'Up (Mbps)': 11.67,
#   'Day': 4,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-21',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 68.12,
#   'Up (Mbps)': 5.77,
#   'Day': 5,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-22',
#   'Delay (ms)': 88,
#   'Down (Mbps)': 69.05,
#   'Up (Mbps)': 11.03,
#   'Day': 6,
#   'Max Temp (°C)': 0.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-23',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 71.79,
#   'Up (Mbps)': 4.01,
#   'Day': 7,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-24',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.63,
#   'Up (Mbps)': 14.45,
#   'Day': 1,
#   'Max Temp (°C)': -2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-25',
#   'Delay (ms)': 125,
#   'Down (Mbps)': 73.12,
#   'Up (Mbps)': 6.86,
#   'Day': 2,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-26',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.17,
#   'Up (Mbps)': 13.72,
#   'Day': 3,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-27',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 68.15,
#   'Up (Mbps)': 6.96,
#   'Day': 4,
#   'Max Temp (°C)': -1.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2021-01-28',
#   'Delay (ms)': 62,
#   'Down (Mbps)': 72.03,
#   'Up (Mbps)': 6.92,
#   'Day': 5,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2021-01-29',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 75.77,
#   'Up (Mbps)': 11.24,
#   'Day': 6,
#   'Max Temp (°C)': -4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-30',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 75.62,
#   'Up (Mbps)': 12.24,
#   'Day': 7,
#   'Max Temp (°C)': -1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-01-31',
#   'Delay (ms)': 93,
#   'Down (Mbps)': 71.81,
#   'Up (Mbps)': 14.6,
#   'Day': 1,
#   'Max Temp (°C)': -2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-01',
#   'Delay (ms)': 69,
#   'Down (Mbps)': 71.04,
#   'Up (Mbps)': 14.45,
#   'Day': 2,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-02',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.96,
#   'Up (Mbps)': 6.48,
#   'Day': 3,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2021-02-03',
#   'Delay (ms)': 125,
#   'Down (Mbps)': 74.57,
#   'Up (Mbps)': 6.25,
#   'Day': 4,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-04',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.17,
#   'Up (Mbps)': 6.83,
#   'Day': 5,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-05',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 69.65,
#   'Up (Mbps)': 13.88,
#   'Day': 6,
#   'Max Temp (°C)': -1.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2021-02-06',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 73.51,
#   'Up (Mbps)': 14.29,
#   'Day': 7,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 2.0},
#  {'Date/Time': '2021-02-07',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 75.06,
#   'Up (Mbps)': 13.88,
#   'Day': 1,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-08',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 50.44,
#   'Up (Mbps)': 4.94,
#   'Day': 2,
#   'Max Temp (°C)': -6.0,
#   'Total Precip (mm)': 3.0},
#  {'Date/Time': '2021-02-09',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.19,
#   'Up (Mbps)': 13.87,
#   'Day': 3,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-10',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 71.19,
#   'Up (Mbps)': 12.68,
#   'Day': 4,
#   'Max Temp (°C)': -5.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-11',
#   'Delay (ms)': 83,
#   'Down (Mbps)': 72.84,
#   'Up (Mbps)': 11.46,
#   'Day': 5,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-12',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 71.15,
#   'Up (Mbps)': 11.7,
#   'Day': 6,
#   'Max Temp (°C)': -5.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-13',
#   'Delay (ms)': 173,
#   'Down (Mbps)': 72.27,
#   'Up (Mbps)': 6.96,
#   'Day': 7,
#   'Max Temp (°C)': -7.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-14',
#   'Delay (ms)': 88,
#   'Down (Mbps)': 72.79,
#   'Up (Mbps)': 13.49,
#   'Day': 1,
#   'Max Temp (°C)': -4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-15',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 71.52,
#   'Up (Mbps)': 6.35,
#   'Day': 2,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 1.0},
#  {'Date/Time': '2021-02-16',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 75.7,
#   'Up (Mbps)': 9.96,
#   'Day': 3,
#   'Max Temp (°C)': -4.5,
#   'Total Precip (mm)': 7.0},
#  {'Date/Time': '2021-02-17',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 64.32,
#   'Up (Mbps)': 11.05,
#   'Day': 4,
#   'Max Temp (°C)': -4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-18',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 71.34,
#   'Up (Mbps)': 11.63,
#   'Day': 5,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 1.6},
#  {'Date/Time': '2021-02-19',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 74.65,
#   'Up (Mbps)': 11.08,
#   'Day': 6,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2021-02-20',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 72.85,
#   'Up (Mbps)': 7.42,
#   'Day': 7,
#   'Max Temp (°C)': -3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-21',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 71.39,
#   'Up (Mbps)': 14.65,
#   'Day': 1,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 7.0},
#  {'Date/Time': '2021-02-22',
#   'Delay (ms)': 75,
#   'Down (Mbps)': 70.47,
#   'Up (Mbps)': 11.63,
#   'Day': 2,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-23',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 71.11,
#   'Up (Mbps)': 11.4,
#   'Day': 3,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-24',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 74.25,
#   'Up (Mbps)': 6.19,
#   'Day': 4,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-25',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 72.52,
#   'Up (Mbps)': 6.22,
#   'Day': 5,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-26',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 72.11,
#   'Up (Mbps)': 5.65,
#   'Day': 6,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-27',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 73.06,
#   'Up (Mbps)': 11.59,
#   'Day': 7,
#   'Max Temp (°C)': 3.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-02-28',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 71.3,
#   'Up (Mbps)': 13.67,
#   'Day': 1,
#   'Max Temp (°C)': 9.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-01',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 73.35,
#   'Up (Mbps)': 13.34,
#   'Day': 2,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-02',
#   'Delay (ms)': 87,
#   'Down (Mbps)': 75.27,
#   'Up (Mbps)': 13.68,
#   'Day': 3,
#   'Max Temp (°C)': nan,
#   'Total Precip (mm)': nan},
#  {'Date/Time': '2021-03-03',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 75.41,
#   'Up (Mbps)': 13.52,
#   'Day': 4,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-04',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 73.57,
#   'Up (Mbps)': 13.96,
#   'Day': 5,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-05',
#   'Delay (ms)': 82,
#   'Down (Mbps)': 69.08,
#   'Up (Mbps)': 6.2,
#   'Day': 6,
#   'Max Temp (°C)': 2.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-06',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 71.06,
#   'Up (Mbps)': 6.93,
#   'Day': 7,
#   'Max Temp (°C)': 0.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-07',
#   'Delay (ms)': 77,
#   'Down (Mbps)': 72.72,
#   'Up (Mbps)': 11.22,
#   'Day': 1,
#   'Max Temp (°C)': 0.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-08',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 73.41,
#   'Up (Mbps)': 11.15,
#   'Day': 2,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-09',
#   'Delay (ms)': 80,
#   'Down (Mbps)': 62.46,
#   'Up (Mbps)': 3.92,
#   'Day': 3,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-10',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 73.0,
#   'Up (Mbps)': 5.55,
#   'Day': 4,
#   'Max Temp (°C)': 16.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-11',
#   'Delay (ms)': 81,
#   'Down (Mbps)': 72.64,
#   'Up (Mbps)': 6.92,
#   'Day': 5,
#   'Max Temp (°C)': 14.0,
#   'Total Precip (mm)': 2.2},
#  {'Date/Time': '2021-03-12',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 74.51,
#   'Up (Mbps)': 13.25,
#   'Day': 6,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-13',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 74.95,
#   'Up (Mbps)': 5.77,
#   'Day': 7,
#   'Max Temp (°C)': 5.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-14',
#   'Delay (ms)': 62,
#   'Down (Mbps)': 71.64,
#   'Up (Mbps)': 5.66,
#   'Day': 1,
#   'Max Temp (°C)': 6.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-15',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.07,
#   'Up (Mbps)': 13.18,
#   'Day': 2,
#   'Max Temp (°C)': 1.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-16',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.6,
#   'Up (Mbps)': 5.6,
#   'Day': 3,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-17',
#   'Delay (ms)': 84,
#   'Down (Mbps)': 71.01,
#   'Up (Mbps)': 11.51,
#   'Day': 4,
#   'Max Temp (°C)': 9.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-18',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 75.45,
#   'Up (Mbps)': 5.87,
#   'Day': 5,
#   'Max Temp (°C)': 6.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-19',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 73.64,
#   'Up (Mbps)': 6.48,
#   'Day': 6,
#   'Max Temp (°C)': 4.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-20',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.58,
#   'Up (Mbps)': 6.38,
#   'Day': 7,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-21',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 70.62,
#   'Up (Mbps)': 6.12,
#   'Day': 1,
#   'Max Temp (°C)': 17.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-22',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 75.93,
#   'Up (Mbps)': 6.12,
#   'Day': 2,
#   'Max Temp (°C)': 19.5,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-23',
#   'Delay (ms)': 62,
#   'Down (Mbps)': 72.28,
#   'Up (Mbps)': 6.58,
#   'Day': 3,
#   'Max Temp (°C)': 19.5,
#   'Total Precip (mm)': 2.0},
#  {'Date/Time': '2021-03-24',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.26,
#   'Up (Mbps)': 6.48,
#   'Day': 4,
#   'Max Temp (°C)': 20.0,
#   'Total Precip (mm)': 0.8},
#  {'Date/Time': '2021-03-25',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 74.1,
#   'Up (Mbps)': 6.83,
#   'Day': 5,
#   'Max Temp (°C)': 16.5,
#   'Total Precip (mm)': 10.0},
#  {'Date/Time': '2021-03-26',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 72.92,
#   'Up (Mbps)': 6.21,
#   'Day': 6,
#   'Max Temp (°C)': 10.0,
#   'Total Precip (mm)': 7.0},
#  {'Date/Time': '2021-03-27',
#   'Delay (ms)': 94,
#   'Down (Mbps)': 71.5,
#   'Up (Mbps)': 6.36,
#   'Day': 7,
#   'Max Temp (°C)': 11.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-28',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 71.67,
#   'Up (Mbps)': 6.06,
#   'Day': 1,
#   'Max Temp (°C)': 8.0,
#   'Total Precip (mm)': 16.0},
#  {'Date/Time': '2021-03-29',
#   'Delay (ms)': 78,
#   'Down (Mbps)': 76.54,
#   'Up (Mbps)': 10.91,
#   'Day': 2,
#   'Max Temp (°C)': 7.0,
#   'Total Precip (mm)': 0.0},
#  {'Date/Time': '2021-03-30',
#   'Delay (ms)': 79,
#   'Down (Mbps)': 70.44,
#   'Up (Mbps)': 6.09,
#   'Day': 3,
#   'Max Temp (°C)': 17.0,
#   'Total Precip (mm)': 1.2}]

# %% [markdown]
# __Use Pymongo to export to MongoDB

# %%
from pymongo import MongoClient as MC
client = MC("localhost", 27017)

# %%
db = client["finalProject"]
collection = db["network"]

# %%
collection.insert_many(complete_dict)

# %% [markdown]
# ![Capture%2045.PNG](attachment:Capture%2045.PNG)

# %% [markdown]
# __Use Mongo's export command to create JSON file

# %% [markdown]
# mongoexport --host localhost --db finalProject --collection network --out C:\Hy_mgdb_data\network.json --jsonArray

# %% [markdown]
# ![Capture%2046.PNG](attachment:Capture%2046.PNG)

# %% [markdown]
# __Ingress the data into SQL Server

# %% [markdown]
# DROP TABLE IF EXISTS NetworkData
# GO
#
# SELECT Network.*
# INTO NetworkData
# FROM OPENROWSET (BULK N'C:\Hy_mgdb_data\network.json', SINGLE_CLOB) AS DATA
# CROSS APPLY OPENJSON(BulkColumn)
# WITH
# (
# 	ID INT,
# 	Date DATE '$."Date/Time"',
# 	Delay DECIMAL '$."Delay (ms)"',
# 	Down DECIMAL(5,2) '$."Down (Mbps)"',
# 	Up DECIMAL(5,2) '$."Up (Mbps)"',
# 	Day SMALLINT '$."Day"',
# 	MaxTemp DECIMAL(5,2) '$."Max Temp (Â°C)"',
# 	Precipitation DECIMAL(5,2) '$."Total Precip (mm)"'
# ) AS Network
#
# SELECT * FROM NetworkData
